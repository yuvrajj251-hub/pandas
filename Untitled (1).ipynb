# %%
import pandas as pd 
a = [1,2,3,4]
new = pd.Series(a)
print(new)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
import pandas as pd 
a=[1,2,3,4]
new = pd.Series(a,index=["x","y","z","q"])
print(new)
# Out:
# x    1
# y    2
# z    3
# q    4
# dtype: int64

# %%
import pandas as pd 
a = [8,9,10,11]
new = pd.Series(a,index=["rollno.1","rollno.2","rollno.3","rollno.4"])
print(new)
# Out:
# rollno.1     8
# rollno.2     9
# rollno.3    10
# rollno.4    11
# dtype: int64

# %%
import pandas as pd 
a={
    "Name":"yuvraj  kunal  rohan",
    "Rollno.":"1  2  3",
    "Marks":"56  89  96"
}
new = pd.Series(a)
print(new)
# Out:
# Name       yuvraj  kunal  rohan
# Rollno.                 1  2  3
# Marks                56  89  96
# dtype: object

# %%
import pandas as pd 
a={
    "name":"10",
    "Rollno.":"20",
    "Marks":"30",
    "class":"40",
    "subject":"50"
}    
new = pd. Series(a)
print(new)
# Out:
# name       10
# Rollno.    20
# Marks      30
# class      40
# subject    50
# dtype: object

# %%
import pandas as pd 
data = {
    "name":["yuvraj","kunal","rohan"],
    "rollno.":[6,7,8],
    "Marks":[78,89,76]
}
new=pd.DataFrame(data)
print(new["rollno."])
# Out:
# 0    6
# 1    7
# 2    8
# Name: rollno., dtype: int64

# %%
import pandas as pd 
import numpy as np
df=pd.DataFrame(data=np.arange(0,30).reshape(6,5),index=["row1","row2","row3","row4","row5","row6"],columns=["columns1","columns2","columns3","columns4","columns5"])
print(df)
# Out:
#       columns1  columns2  columns3  columns4  columns5
# row1         0         1         2         3         4
# row2         5         6         7         8         9
# row3        10        11        12        13        14
# row4        15        16        17        18        19
# row5        20        21        22        23        24
# row6        25        26        27        28        29

# %%
df.head()
# Out:
#       columns1  columns2  columns3  columns4  columns5
# row1         0         1         2         3         4
# row2         5         6         7         8         9
# row3        10        11        12        13        14
# row4        15        16        17        18        19
# row5        20        21        22        23        24

# %%
df.tail()
# Out:
#       columns1  columns2  columns3  columns4  columns5
# row2         5         6         7         8         9
# row3        10        11        12        13        14
# row4        15        16        17        18        19
# row5        20        21        22        23        24
# row6        25        26        27        28        29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, row1 to row6
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   columns1  6 non-null      int64
#  1   columns2  6 non-null      int64
#  2   columns3  6 non-null      int64
#  3   columns4  6 non-null      int64
#  4   columns5  6 non-null      int64
# dtypes: int64(5)
# memory usage: 288.0+ bytes

# %%
import pandas as pd 
a=[1,2,3,4]
new=pd.Series(a)
print(new)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
import pandas as pd 
a=[1,2,3,4]
new=pd.Series(a,index=["yuvraj","kd","rohan","kunal"])
print(new)
# Out:
# yuvraj    1
# kd        2
# rohan     3
# kunal     4
# dtype: int64

# %%
import pandas as pd 
a=[8,9,10,11]
new=pd.Series(a,index=["Rollno.1","Rollno.2","Rollno.3","Rollno.4"])
print(new)
# Out:
# Rollno.1     8
# Rollno.2     9
# Rollno.3    10
# Rollno.4    11
# dtype: int64

# %%
import pandas as pd 
a={
    "name":["yuvraj","kunal","rohan"],
    "rollno.":[2,11,3],
    "marks":[65,57.69]
}
new=pd.Series(a)
print(new)
# Out:
# name       [yuvraj, kunal, rohan]
# rollno.                [2, 11, 3]
# marks                 [65, 57.69]
# dtype: object

# %%
import pandas as pd 
a={
    "name":[10],
    "rollno":[20],
    "marks":[30]
}
new=pd.Series(a)
print(new)
# Out:
# name      [10]
# rollno    [20]
# marks     [30]
# dtype: object

# %%
import pandas as pd 
data={
    "name":["yuvraj","kunal",None],
    "rollno":[1,3,5],
    "marks":[67,87,65]
}
df=pd.DataFrame(data)
print(df)
# Out:
#      name  rollno  marks
# 0  yuvraj       1     67
# 1   kunal       3     87
# 2    None       5     65

# %%
# import pandas as pd 
# import numpy as np
# pd.DataFrame(data=np.arange(0,40).reshape(8,5),index=["row1","row2","row3","row4","row5","row6","row7","row8"],columns=["columns1","columns2","columns3","columns4","columns5"])
# Out:
#       columns1  columns2  columns3  columns4  columns5
# row1         0         1         2         3         4
# row2         5         6         7         8         9
# row3        10        11        12        13        14
# row4        15        16        17        18        19
# row5        20        21        22        23        24
# row6        25        26        27        28        29
# row7        30        31        32        33        34
# None        35        36        37        38        39

# %%
# df.head()
# Out:
#       columns1  columns2  columns3  columns4  columns5
# row1         0         1         2         3         4
# row2         5         6         7         8         9
# row3        10        11        12        13        14
# row4        15        16        17        18        19
# row5        20        21        22        23        24

# %%
# df.tail()
# Out:
#       columns1  columns2  columns3  columns4  columns5
# row4        15        16        17        18        19
# row5        20        21        22        23        24
# row6        25        26        27        28        29
# row7        30        31        32        33        34
# row8        35        36        37        38        39

# %%
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, row1 to row8
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   columns1  8 non-null      int64
#  1   columns2  8 non-null      int64
#  2   columns3  8 non-null      int64
#  3   columns4  8 non-null      int64
#  4   columns5  8 non-null      int64
# dtypes: int64(5)
# memory usage: 384.0+ bytes

# %%
# import pandas as pd 
# import numpy as np
# df=pd.DataFrame(data=np.arange(0,50).reshape(10,5),index=["row1","row2",None,"row4","row5","row6","row7","row8","row9","row10"],columns=["columns1","columns2","columns3","columns4,"columns5"])      
# print(df)
# Out:
#        columns1  columns2  columns3  columns4  columns5
# row1          0         1         2         3         4
# row2          5         6         7         8         9
# None         10        11        12        13        14
# row4         15        16        17        18        19
# row5         20        21        22        23        24
# row6         25        26        27        28        29
# row7         30        31        32        33        34
# row8         35        36        37        38        39
# row9         40        41        42        43        44
# row10        45        46        47        48        49

# %%
# df.head()
# Out:
#       columns1  columns2  columns3  columns4  columns5
# row1         0         1         2         3         4
# row2         5         6         7         8         9
# None        10        11        12        13        14
# row4        15        16        17        18        19
# row5        20        21        22        23        24

# %%
# df.tail(3)
# Out:
#        columns1  columns2  columns3  columns4  columns5
# row8         35        36        37        38        39
# row9         40        41        42        43        44
# row10        45        46        47        48        49

# %%
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, row1 to row10
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   columns1  10 non-null     int64
#  1   columns2  10 non-null     int64
#  2   columns3  10 non-null     int64
#  3   columns4  10 non-null     int64
#  4   columns5  10 non-null     int64
# dtypes: int64(5)
# memory usage: 480.0+ bytes

# %%
# df.head()
# Out:
#      name  rollno  marks
# 0  yuvraj       1     67
# 1   kunal       3     87
# 2    None       5     65

# %%
# df.tail()
# Out:
#      name  rollno  marks
# 0  yuvraj       1     67
# 1   kunal       3     87
# 2    None       5     65

# %%
# df.info()

# %%
import pandas as pd 
import numpy as np
pd.DataFrame(data=np.arange(0,60).reshape(12,5),index=["row1","row2","row3","row4","row5","row6","row7","row8","row9","row10","row11","row12"],columns=["columns1","columns2","columns3","columns4","columns5"])
# Out:
#        columns1  columns2  columns3  columns4  columns5
# row1          0         1         2         3         4
# row2          5         6         7         8         9
# row3         10        11        12        13        14
# row4         15        16        17        18        19
# row5         20        21        22        23        24
# row6         25        26        27        28        29
# row7         30        31        32        33        34
# row8         35        36        37        38        39
# row9         40        41        42        43        44
# row10        45        46        47        48        49
# row11        50        51        52        53        54
# row12        55        56        57        58        59

# %%
import pandas as pd 
import numpy as np
pd.DataFrame(data=np.arange(0,90).reshape(18,5),index=["row1","row2","row3","row4","row5","row6","row7","row8","row9","row10","row11","row12","row13","row14","row15","row16","row17","row18"],columns=["columns1","columns2","columns3","columns4","columns5"])
# Out:
#        columns1  columns2  columns3  columns4  columns5
# row1          0         1         2         3         4
# row2          5         6         7         8         9
# row3         10        11        12        13        14
# row4         15        16        17        18        19
# row5         20        21        22        23        24
# row6         25        26        27        28        29
# row7         30        31        32        33        34
# row8         35        36        37        38        39
# row9         40        41        42        43        44
# row10        45        46        47        48        49
# row11        50        51        52        53        54
# row12        55        56        57        58        59
# row13        60        61        62        63        64
# row14        65        66        67        68        69
# row15        70        71        72        73        74
# row16        75        76        77        78        79
# ...

# %%
import pandas as pd 
import numpy as np
pd.DataFrame(data=np.arange(0,90).reshape(18,5),index=["row1","row2","row3","row4","row5","row6","row7","row8","row9","row10","row11","row12","row13","row14","row15","row16","row17","row18"],columns=["columns1","columns2","columns3","columns4","columns5"])
# Out:
#        columns1  columns2  columns3  columns4  columns5
# row1          0         1         2         3         4
# row2          5         6         7         8         9
# row3         10        11        12        13        14
# row4         15        16        17        18        19
# row5         20        21        22        23        24
# row6         25        26        27        28        29
# row7         30        31        32        33        34
# row8         35        36        37        38        39
# row9         40        41        42        43        44
# row10        45        46        47        48        49
# row11        50        51        52        53        54
# row12        55        56        57        58        59
# row13        60        61        62        63        64
# row14        65        66        67        68        69
# row15        70        71        72        73        74
# row16        75        76        77        78        79
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Kuldeep\Downloads\image\Rani Work\data.csv")
print(df)
# Out:
#      name  age class
# 0  yuvraj   20   abc
# 1    pari   20   abc
# 2      kd   20   abc

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Kuldeep\Documents\exceldata.xlsx")
print(df)
# Out:
#       name   rollno class
# 0    yuvraj       1   abc
# 1      pari       2   abc
# 2   kuldeep       3   abc
# 3   kuldeep       3   abc
# 4   kuldeep       3   abc
# 5   kuldeep       3   abc
# 6   kuldeep       3   abc
# 7   kuldeep       3   abc
# 8   kuldeep       3   abc
# 9   kuldeep       3   abc
# 10  kuldeep       3   abc
# 11  kuldeep       3   abc

# %%
import pandas as pd
df = pd.read_json(r"C:\Users\Kuldeep\Downloads\image\Rani Work\files.json")
print(df)
# Out:
#      name  age  marks
# 0  Yuvraj   20     80
# 1  Yuvraj   20     80
# 2  Yuvraj   20     80
# 3  Yuvraj   20     80
# 4  Yuvraj   20     80
# 5  Yuvraj   20     80
# 6  Yuvraj   20     80

# %%
df[["age"]]
# Out:
#    age
# 0   20
# 1   20
# 2   20
# 3   20
# 4   20
# 5   20
# 6   20

# %%
df[["marks"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df[["marks"]]
#
# NameError: name 'df' is not defined

# %%
df.iloc[5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.iloc[5]
#
# NameError: name 'df' is not defined

# %%
df["class"]=[1,2,3,4,5,6,7]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df["class"]=[1,2,3,4,5,6,7]
#       2 df
#
# NameError: name 'df' is not defined

# %%
df.loc[len(df)]=["kunal",22,67,10]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.loc[len(df)]=["kunal",22,67,10]
#       2 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Kuldeep\Downloads\image\Rani Work\Works.csv")
print(df)
# Out:
#       name  age  marks
# 0   yuvraj   20     78
# 1  kuldeep   20     87
# 2     pari   20     67
# 3    kunal   20     89
# 4    rohan   20     75

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Kuldeep\Documents\excel.xlsx")
print(df)
# Out:
#       name   rollno class
# 0    yuvraj       1   abc
# 1      pari       2   abc
# 2   kuldeep       3   abc
# 3   kuldeep       3   abc
# 4   kuldeep       3   abc
# 5   kuldeep       3   abc
# 6   kuldeep       3   abc
# 7   kuldeep       3   abc
# 8   kuldeep       3   abc
# 9   kuldeep       3   abc
# 10  kuldeep       3   abc
# 11  kuldeep       3   abc

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Kuldeep\Documents\book3.xlsx")
print(df)
# Out:
#      ID            Name   Age        City   Salary  Department
# 0   101     Amit Sharma  28.0       Delhi  45000.0   Marketing
# 1   102     Priya Verma  32.0      Mumbai      NaN          HR
# 2   103     Rahul Singh  26.0   Bangalore  48000.0          IT
# 3   104    Sneha Kapoor  30.0        Pune  51000.0     Finance
# 4   105    Vikram Patel  35.0   Ahmedabad  60000.0  Operations
# 5   106      Neha Gupta   NaN     Kolkata  47000.0       Sales
# 6   107     Arjun Mehta  29.0     Chennai  49000.0          IT
# 7   108    Kavita Joshi  31.0      Jaipur      NaN          HR
# 8   109       Rohan Das  34.0   Hyderabad  58000.0     Finance
# 9   110     Anjali Nair  25.0       Kochi  46000.0   Marketing
# 10  111    Manish Yadav  33.0     Lucknow  55000.0       Sales
# 11  112     Pooja Singh  28.0      Bhopal  48000.0          HR
# 12  113    Deepak Kumar   NaN       Patna  61000.0  Operations
# 13  114     Ritika Jain  29.0      Indore  50000.0     Finance
# ...

# %%
x = df["Age"].mean()

df.fillna({"Age": x}, inplace=True)
df
# Out:
#      ID            Name    Age        City   Salary  Department
# 0   101     Amit Sharma  28.00       Delhi  45000.0   Marketing
# 1   102     Priya Verma  32.00      Mumbai      NaN          HR
# 2   103     Rahul Singh  26.00   Bangalore  48000.0          IT
# 3   104    Sneha Kapoor  30.00        Pune  51000.0     Finance
# 4   105    Vikram Patel  35.00   Ahmedabad  60000.0  Operations
# 5   106      Neha Gupta  30.76     Kolkata  47000.0       Sales
# 6   107     Arjun Mehta  29.00     Chennai  49000.0          IT
# 7   108    Kavita Joshi  31.00      Jaipur      NaN          HR
# 8   109       Rohan Das  34.00   Hyderabad  58000.0     Finance
# 9   110     Anjali Nair  25.00       Kochi  46000.0   Marketing
# 10  111    Manish Yadav  33.00     Lucknow  55000.0       Sales
# 11  112     Pooja Singh  28.00      Bhopal  48000.0          HR
# 12  113    Deepak Kumar  30.76       Patna  61000.0  Operations
# 13  114     Ritika Jain  29.00      Indore  50000.0     Finance
# ...

# %%
x = df["Age"].median()

df.fillna({"Age": x}, inplace=True)
df
# Out:
#      ID            Name    Age        City   Salary  Department
# 0   101     Amit Sharma  28.00       Delhi  45000.0   Marketing
# 1   102     Priya Verma  32.00      Mumbai      NaN          HR
# 2   103     Rahul Singh  26.00   Bangalore  48000.0          IT
# 3   104    Sneha Kapoor  30.00        Pune  51000.0     Finance
# 4   105    Vikram Patel  35.00   Ahmedabad  60000.0  Operations
# 5   106      Neha Gupta  30.76     Kolkata  47000.0       Sales
# 6   107     Arjun Mehta  29.00     Chennai  49000.0          IT
# 7   108    Kavita Joshi  31.00      Jaipur      NaN          HR
# 8   109       Rohan Das  34.00   Hyderabad  58000.0     Finance
# 9   110     Anjali Nair  25.00       Kochi  46000.0   Marketing
# 10  111    Manish Yadav  33.00     Lucknow  55000.0       Sales
# 11  112     Pooja Singh  28.00      Bhopal  48000.0          HR
# 12  113    Deepak Kumar  30.76       Patna  61000.0  Operations
# 13  114     Ritika Jain  29.00      Indore  50000.0     Finance
# ...

# %%
x = df["Age"].mode()[0]

df.fillna({"Age": x}, inplace=True)
df
# Out:
#      ID            Name    Age        City   Salary  Department
# 0   101     Amit Sharma  28.00       Delhi  45000.0   Marketing
# 1   102     Priya Verma  32.00      Mumbai      NaN          HR
# 2   103     Rahul Singh  26.00   Bangalore  48000.0          IT
# 3   104    Sneha Kapoor  30.00        Pune  51000.0     Finance
# 4   105    Vikram Patel  35.00   Ahmedabad  60000.0  Operations
# 5   106      Neha Gupta  30.76     Kolkata  47000.0       Sales
# 6   107     Arjun Mehta  29.00     Chennai  49000.0          IT
# 7   108    Kavita Joshi  31.00      Jaipur      NaN          HR
# 8   109       Rohan Das  34.00   Hyderabad  58000.0     Finance
# 9   110     Anjali Nair  25.00       Kochi  46000.0   Marketing
# 10  111    Manish Yadav  33.00     Lucknow  55000.0       Sales
# 11  112     Pooja Singh  28.00      Bhopal  48000.0          HR
# 12  113    Deepak Kumar  30.76       Patna  61000.0  Operations
# 13  114     Ritika Jain  29.00      Indore  50000.0     Finance
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Kuldeep\Downloads\image\Rani Work\rohan.csv")
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse       Calories
# 0         60    2024-01-01    110     130.0            409
# 1         60    01/02/2024    117     145.0            479
# 2         45    2024.01.03    103     135.0            340
# 3         30    Jan 4 2024    109     130.0            NaN
# 4         60    2024/01/05    NaN     140.0            374
# 5         90      05-01-24    120     150.0       500 kcal
# 6         60           NaN    115     138.0            390
# 7         45    2024-01-07      0     120.0            300
# 8         30    2024-13-08    105     128.0            280
# 9         60  8th Jan 2024    112       NaN            410
# 10        45    2024-01-10    118     145.0            -50
# 11        30           NaN    100     120.0            250
# 12        60    2024-01-11  error     135.0            370
# 13        45     Yesterday    110     140.0            400
# 14        30    2024-01-13    108     132.0  three hundred

# %%
df.dropna(subset=['Date'], inplace = True)
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse       Calories
# 0         60    2024-01-01    110     130.0            409
# 1         60    01/02/2024    117     145.0            479
# 2         45    2024.01.03    103     135.0            340
# 3         30    Jan 4 2024    109     130.0            NaN
# 4         60    2024/01/05    NaN     140.0            374
# 5         30      05-01-24    120     150.0       500 kcal
# 7         45    2024-01-07      0     120.0            300
# 8         30    2024-13-08    105     128.0            280
# 9         60  8th Jan 2024    112       NaN            410
# 10        45    2024-01-10    118     145.0            -50
# 12        60    2024-01-11  error     135.0            370
# 13        45     Yesterday    110     140.0            400
# 14        30    2024-01-13    108     132.0  three hundred

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Kuldeep\Documents\wrong data.xlsx")
print(df)
# Out:
#       Name  Class   Age       City  Marks
# 0     Amit     10  15.0      Delhi     85
# 1     Riya     12  17.0     Mumbai     90
# 2    Sohan     11  16.0      Delhi     78
# 3     Neha     10   NaN  Bangalore     88
# 4    Rahul     12  18.0       Pune     92
# 5    Priya     11  16.0      Delhi     80
# 6      NaN     12  17.0     Mumbai     86
# 7    Sneha     10  15.0        NaN     89
# 8    Arjun    789  16.0       Pune     84
# 9    Meena     10  15.0      Delhi     82
# 10   Vikas     12  18.0     Mumbai     91
# 11  Anjali     11  16.0  Bangalore    997

# %%
df.loc[8, 'Class'] = 34
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.loc[8, 'Class'] = 34
#       2 df
#
# NameError: name 'df' is not defined

# %%
for x in df.index:
  if df.loc[x, "Marks"] > 80:
    df.loc[x, "Marks"] = 76
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for x in df.index:
#       2   if df.loc[x, "Marks"] > 80:
#       3     df.loc[x, "Marks"] = 76
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Kuldeep\Downloads\image\Rani Work\kunal.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv(r"C:\Users\Kuldeep\Downloads\image\Rani Work\kunal.csv")
#       3 print(df)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Kuldeep\Downloads\image\Rani Work\kunal.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv(r"C:\Users\Kuldeep\Downloads\image\Rani Work\kunal.csv")
#       3 print(df)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 17.9 MB/s  0:00:009.3 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 19.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 16.6 MB/s  0:00:001.1 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 7.4 MB/s  0:00:00m 7.7 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [matplotlib]0m  9/10 [matplotlib]util]
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.
